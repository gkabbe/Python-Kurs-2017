# %% [markdown]
# # Visualisierung von Numpy Arrays
#
# ## Matplotlib

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


x = [1, 2, 3, 4, 5]
y = [10, 9.5, 8, 9, 7]

plt.plot(x, y)
plt.show()
# Out:
# /scratch/kabbe/programs/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
x = np.linspace(0, 6 * np.pi, 200)
y = np.sin(x)

plt.plot(x, y)
plt.show()
# Out:
# /scratch/kabbe/programs/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# Plotten nur die Werte, die größer Null sind

plt.plot(x[y > 0], y[y > 0], "x")
plt.show()
# Out:
# /scratch/kabbe/programs/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
buchstaben = np.char.array(list("ABCDEFGH"))
zahlen = np.arange(1, 9).astype(str)

# %%
B, Z = np.meshgrid(buchstaben, zahlen.astype(str))

# %%
B + Z
# Out:
# chararray([['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1'],
#            ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2'],
#            ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3'],
#            ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4'],
#            ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5'],
#            ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6'],
#            ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7'],
#            ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8']],
#           dtype='<U22')
